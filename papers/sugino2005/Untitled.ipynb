# %%
!  mv ~/Downloads/sandbox.xlsx sugino_types.xslx

# %%
import pandas as pd
types_to_create = pd.read_excel("sugino_types.xslx",sheet_name="Sheet6")

# %%
types_to_create
# Out:
#         Len                part of        P361 neurotransmitter     P1056
# 0    CT6-CG       Cingulate cortex   Q19772725              Glu  Q1532394
# 1    G30-AM       Amygdala Lateral  Q105664967              Glu  Q1532394
# 2    G30-CG       Cingulate cortex   Q19772725             GABA   Q210021
# 3    G30-S1   Somatosensory cortex   Q64926247             GABA   Q210021
# 4    G42-CG       Cingulate cortex   Q19772725             GABA   Q210021
# 5    G42-LG            Dorsal LGN   Q105665011             GABA   Q210021
# 6    GIN-CG       Cingulate cortex   Q19772725             GABA   Q210021
# 7    GIN-HP            Hippocampus      Q48360             GABA   Q210021
# 8   YFPH-AM  Amygdala  Basolateral    Q4867818              Glu  Q1532394
# 9   YFPH-CG       Cingulate cortex   Q19772725              Glu  Q1532394
# 10  YFPH-HP            Hippocampus      Q48360              Glu  Q1532394
# 11  YFPH-S1   Somatosensory cortex   Q64926247              Glu  Q1532394

# %%
prop = "P31"
value = "Q189118"
reference_article = "Q28288068"
for i, row in types_to_create.iterrows():
    
        print("CREATE")
        s = "LAST"
        p = "|" + prop + "|"
        o = value
        rp1 = "|S248|"
        ro1 = reference_article
        print("LAST|Len|" + '"'+row["Len"]+ '"')
        print("LAST|P361|" +row["P361"]+rp1+ro1)
        print("LAST|P1056|" +row["P1056"]+rp1+ro1)
        print("LAST|P703|" + "Q83310"+rp1+ro1)
        print("LAST|P279|" + "Q43054"+rp1+ro1)
        print(s+p+o+rp1+ro1)
# Out:
# CREATE
# LAST|Len|"CT6-CG"
# LAST|P361|Q19772725|S248|Q28288068
# LAST|P1056|Q1532394|S248|Q28288068
# LAST|P703|Q83310|S248|Q28288068
# LAST|P279|Q43054|S248|Q28288068
# LAST|P31|Q189118|S248|Q28288068
# CREATE
# LAST|Len|"G30-AM"
# LAST|P361|Q105664967|S248|Q28288068
# LAST|P1056|Q1532394|S248|Q28288068
# LAST|P703|Q83310|S248|Q28288068
# LAST|P279|Q43054|S248|Q28288068
# LAST|P31|Q189118|S248|Q28288068
# CREATE
# LAST|Len|"G30-CG"
# LAST|P361|Q19772725|S248|Q28288068
# LAST|P1056|Q210021|S248|Q28288068
# LAST|P703|Q83310|S248|Q28288068
# LAST|P279|Q43054|S248|Q28288068
# LAST|P31|Q189118|S248|Q28288068
# CREATE
# LAST|Len|"G30-S1"
# LAST|P361|Q64926247|S248|Q28288068
# LAST|P1056|Q210021|S248|Q28288068
# LAST|P703|Q83310|S248|Q28288068
# LAST|P279|Q43054|S248|Q28288068
# LAST|P31|Q189118|S248|Q28288068
# CREATE
# LAST|Len|"G42-CG"
# LAST|P361|Q19772725|S248|Q28288068
# LAST|P1056|Q210021|S248|Q28288068
# LAST|P703|Q83310|S248|Q28288068
# LAST|P279|Q43054|S248|Q28288068
# ...
