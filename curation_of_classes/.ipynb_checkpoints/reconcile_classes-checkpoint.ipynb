# %%
import pandas as pd

# %%
! mv /home/lubianat/Downloads/Biocuration\ of\ Cell\ Classes\ for\ Wikidata.xlsx classes.xlsx

# %%
cells = pd.read_excel("classes.xlsx", sheet_name="cell classes")

# %%
cells.head(2)
# Out:
#                                                label  \
# 0                      fetal liver island macrophage
# 1  mouse erythroblastic island-associated macrophage
#
#                  description  \
# 0                  cell type
# 1  cell type in Mus musculus
#
#                                              aliases instance of  \
# 0                                                NaN   cell type
# 1  F4/80+ island macrophages | FL island macrophages   cell type
#
#                      subclass of found in taxon   stated in  \
# 0                     macrophage            NaN  Q106234628
# 1  fetal liver island macrophage   Mus musculus  Q106234628
#
#   described by source     part of  stated as Unnamed: 10 Unnamed: 11  \
# 0                 NaN  fetal liver       NaN         NaN         NaN
# 1          Q106234628  fetal liver       NaN         NaN         NaN
#
#   Unnamed: 12 Unnamed: 13  Unnamed: 14 Unnamed: 15
# 0         NaN         NaN          NaN         NaN
# 1         NaN         NaN          NaN         NaN

# %%
# %run dicts.py

# %%
import re
for index, row in cells.iterrows():
    label = row["label"]
    description = row["description"]
    aliases = row["aliases"]
    stated_in = row["stated in"]
    described_by_source = row["described by source"]

    try:
        instance = instance_dict[row["instance of"]]
        
        if  re.findall("Q[0-9]*", row["subclass of"]):
            subclass = row["subclass of"]
        else:
            subclass = subclass_dict[row["subclass of"]]
            
        

        print("CREATE")
        
        try:
            taxon = taxon_dict[row["found in taxon"]]                    
            print(f"LAST|P703|{taxon}|S248|{stated_in}")

        except:
            pass
        
        
        try:
            part_of = part_of_dict[row["part of "]]
            print(f"LAST|P361|{part_of}|S248|{stated_in}")
        except:
            pass

        print(f'LAST|Len|"{label}"')
        print(f'LAST|Den|"{description}"')
        if not str(aliases) == "nan":
            print(f'LAST|Aen|"{aliases}"')
        print(f"LAST|P31|{instance}|S248|{stated_in}")
        print(f"LAST|P279|{subclass}")

        if not str(described_by_source) == "nan":
            print(f'LAST|P1343|{described_by_source}')
        print("")
        
    except:
        print("missing: " + str(row["subclass of"]))
        pass
# Out:
# CREATE
# LAST|P361|Q104539102|S248|Q106234628
# LAST|Len|"fetal liver island macrophage"
# LAST|Den|"cell type"
# LAST|P31|Q189118|S248|Q106234628
# LAST|P279|Q184204
#
# missing: fetal liver island macrophage
# missing: erythroblast
# CREATE
# LAST|P703|Q83310|S248|Q106234628
# LAST|P361|Q104539102|S248|Q106234628
# LAST|Len|"E13.5 murine FL F4/80+ macrophages"
# LAST|Den|"cell type in Mus musculus"
# LAST|P31|Q189118|S248|Q106234628
# LAST|P279|Q184204
#
# CREATE
# LAST|P703|Q83310|S248|Q106234628
# LAST|P361|Q9371|S248|Q106234628
# LAST|Len|"mouse adult spleen F4/80+ macrophage"
# LAST|Den|"cell type in Mus musculus"
# LAST|P31|Q189118|S248|Q106234628
# LAST|P279|Q184204
#
# CREATE
# LAST|P703|Q83310|S248|Q106234628
# LAST|P361|Q104539102|S248|Q106234628
# LAST|Len|"mouse EKLF-expressing macrophage"
# LAST|Den|"cell type in Mus musculus"
# LAST|P31|Q189118|S248|Q106234628
# LAST|P279|Q184204
#
# missing: fetal liver island macrophage
# missing: Human fetal liver island macrophage
# CREATE
# LAST|P703|Q15978631|S248|Q90617724
# LAST|Len|"megakaryocyte–erythroid–mast cell progenitor"
# LAST|Den|"cell class in Homo sapiens"
# LAST|Aen|"MEMP"
# LAST|P31|Q104852483|S248|Q90617724
# LAST|P279|Q7868
#
# missing: neural crest cell
# CREATE
# LAST|Len|"zebrafish sensory dorsal root ganglion (DRG) progenitors"
# LAST|Den|"cell type in Danio rerio"
# LAST|P31|Q189118|S248|Q106248504
# LAST|P279|Q1896218
#
# missing: pigment cell
# missing: melanophore
# missing: xanthophore
# missing: iridophore
# CREATE
# LAST|Len|"zebrafish pigment progenitor cell"
# LAST|Den|"cell type in Danio rerio"
# LAST|P31|Q189118|S248|Q106248504
# LAST|P279|Q1896218
#
# missing: enteric neural crest cell
# missing: enteric neuron
# missing: epithelial cell
# missing: epithelial cell
# missing: epithelial cell
# missing: epithelial cell
# missing: epithelial cell
# missing: epithelial cell
# missing: epididymal cell
# missing: mouse epididymal cell
# missing: mouse epididymal cell
# missing: mouse epididymal cell
# missing: mouse epididymal cell
# missing: mouse epididymal cell
# missing: mouse epididymal cell
# missing: mouse epididymal  principal cell
# missing: mouse epididymal  principal cell
# missing: epithelial cell
# missing: mouse epididymal clear cell
# missing: muscle cell
# missing: human dendritic cell
# missing: human AS DCs
# missing: human AS DCs
# CREATE
# LAST|P703|Q15978631|S248|Q34555562
# LAST|Len|"human cDC progenitor"
# LAST|Den|"cell type in Homo sapiens"
# LAST|Aen|"human circulating cDC progenitor"
# LAST|P31|Q189118|S248|Q34555562
# LAST|P279|Q7868
# LAST|P1343|Q34555562
#
# CREATE
# LAST|P703|Q15978631|S248|Q34555562
# LAST|Len|"human blasticplasmacytoid DC neoplasia "
# LAST|Den|"cell type in Homo sapiens"
# LAST|Aen|"BPDCN cells"
# LAST|P31|Q189118|S248|Q34555562
# LAST|P279|Q7868
# LAST|P1343|Q34555562
#
# missing: human dendritic cell
# missing: human CD11C+ conventional dendrintic cells
# missing: human CD1C+ cDC
# missing: human CD1C+ cDC
# missing: human dendritic cell
# missing: human dendritic cell
# missing: human CD11C+ conventional dendrintic cells
# missing: human CD11C+ conventional dendrintic cells
# missing: human CD11C+ conventional dendrintic cells
# missing: human CD11C+ conventional dendrintic cells
# missing: hepatic portal vein endothelial cells
# missing: periportal hepatocyte
# missing: central venous hepatocytes
# missing: central venous hepatocytes
# missing:  interzonal hepatocyte
# missing: hepatic stem cell
# missing: hepatic B cell
# missing: immune cell
# missing: immune cell
# missing: Langerhans cell
# missing: Langerhans cell
# missing: cerebellar granule cell precursor
# missing: Purkinje cell
# missing: thymic epithelial cell
# missing: T-cell
# missing: T-cell
# missing: double-negative T cell
# missing: double-positive T cell
# missing: CD8αα+ T Cell
# missing: thymic fibroblast
# missing: human thymic fibroblast
# missing: human thymic fibroblast
# missing: medullary thymic epithelial cell
# missing: cortical thymic epithelial cell
# missing: cortical thymic epithelial cell
# missing: medullary thymic epithelial cell
# missing: medullary thymic epithelial cell
# missing: medullary thymic epithelial cell
# missing: PSMB11-positive cTECs
# missing: KRT14-positive mTEC
# missing: AIRE-expressing mTEC
# missing: KRT1-expressing mTEC
# missing: medullary thymic epithelial cell
# missing: medullary thymic epithelial cell
# missing: T cell
# missing: T cell
# CREATE
# LAST|P703|Q15978631|S248|Q89808480
# LAST|Len|" human differentiating Tregs"
# LAST|Den|"cell type in Homo sapiens"
# LAST|P31|Q189118|S248|Q89808480
# LAST|P279|Q7868
#
# missing: human CD8αα+ T Cell
# missing: human CD8αα+ T Cell
# missing: human CD8αα+ T Cell
# missing: T cell
# missing: nan
# CREATE
# LAST|Len|"distal convoluted tubule cell"
# LAST|Den|"cell type"
# LAST|Aen|"DCT cell"
# LAST|P31|Q189118|S248|Q89808480
# LAST|P279|Q7868
#
# missing: distal convoluted tubule cell
# CREATE
# LAST|Len|"ascending loop  of  Henle cell"
# LAST|Den|"cell type"
# LAST|P31|Q189118|S248|Q89808480
# LAST|P279|Q7868
#
# missing: ascending loop  of  Henle cell
# CREATE
# LAST|Len|"descending loop of Henle cells"
# LAST|Den|"cell type"
# LAST|P31|Q189118|S248|Q89808480
# LAST|P279|Q7868
#
# missing: descending loop of Henle cells
# missing: Intercalated cell of collecting duct of renal tubule
# missing: Intercalated cell of collecting duct of renal tubule
# missing: alpha intercalated cell of the collecting duct
# missing: beta intercalated cell | B-IC
# missing: cell of the collecting duct
# missing: epidermal cell
# missing: epidermal cell
# missing: keratinized cell of epidermis
# missing: hair follicle cell
# missing: hair follicle cell
# missing: hair follicle cell
# missing: hair follicle cell
# missing: enteroendocrine cell
# missing: mouse tuft cell
# missing: mouse tuft cell
# missing: Q455445
# missing: Q106395109
# missing: Q106395116
# CREATE
# LAST|Len|"Leshmania major procyclic promastigote"
# LAST|Den|"cell type in Leishmania major"
# LAST|P31|Q189118|S248|Q36368053
# LAST|P279|Q106395122
#
# CREATE
# LAST|Len|"Trypanosoma cruzi epimastigote"
# LAST|Den|"cell type in Trypanosoma cruzi"
# LAST|P31|Q189118|S248|Q36368053
# LAST|P279|Q106395149
#
# CREATE
# LAST|Len|"Trypanosoma cruzi trypomastigote"
# LAST|Den|"cell type in Trypanosoma cruzi"
# LAST|P31|Q189118|S248|Q36368053
# LAST|P279|Q106395156
#
# CREATE
# LAST|Len|"Trypanosoma cruzi metacyclic trypomastigote"
# LAST|Den|"cell type in Trypanosoma cruzi"
# LAST|P31|Q189118|S248|Q36368053
# LAST|P279|Q106395167
#
# CREATE
# LAST|Len|"Trypanosoma cruzi procyclic trypomastigote"
# LAST|Den|"cell type in Trypanosoma cruzi"
# LAST|P31|Q189118|S248|Q36368053
# LAST|P279|Q106395172
#
# CREATE
# LAST|Len|"Trypanosoma brucei epimastigote"
# LAST|Den|"cell type in Trypanosoma brucei"
# LAST|P31|Q189118|S248|Q36368053
# LAST|P279|Q106395149
#
# CREATE
# LAST|Len|"Trypanosoma brucei trypomastigote"
# LAST|Den|"cell type in Trypanosoma brucei"
# LAST|P31|Q189118|S248|Q36368053
# LAST|P279|Q106395156
#
# CREATE
# LAST|Len|"Trypanosoma brucei metacyclic trypomastigote"
# LAST|Den|"cell type in Trypanosoma brucei"
# LAST|P31|Q189118|S248|Q36368053
# LAST|P279|Q106395167
#
# CREATE
# LAST|Len|"Trypanosoma brucei procyclic trypomastigote"
# LAST|Den|"cell type in Trypanosoma brucei"
# LAST|P31|Q189118|S248|Q36368053
# LAST|P279|Q106395172

# %%
if "Q1"):
    print('s')
# Out:
# s
