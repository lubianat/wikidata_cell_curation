# %%
import os
import pandas as pd
from dicts import *
import re
import pickle
import time
from wikidataintegrator import wdi_login, wdi_core
import getpass


os.system(
    "wget -O cell_classes.xlsx https://docs.google.com/spreadsheets/d/e/2PACX-1vTanLtzxD6OXpu3Ze4aNITlIMZEqfK3qrrcNiwFE6kA-YVnuzULp3dG3oYIe5gYAVj28QWZnGwzN_H6/pub\?output\=xlsx"
)

cell_markers = pd.read_excel("cell_classes.xlsx", sheet_name="cell markers")

# %%
cell_markers
# Out:
#                                             cell class  \
# 0                               mouse glycynergic cell
# 1    mouse erythroblastic island-associated macrophage
# 2    mouse erythroblastic island-associated macrophage
# 3    mouse erythroblastic island-associated macrophage
# 4                                zebrafish melanophore
# ..                                                 ...
# 143                                      mouse mTEC IV
# 144                   mouse proximal tubule S1/S2 cell
# 145              mouse proximal tubule S3 type 1 cell
# 146               mouse proximal tubule S3 type 2 cell
# 147                               mouse renal pericyte
#
#                                              marker    stated in  \
# 0                                              GlyT2  Q101212121
# 1                                              F4/80  Q106234628
# 2                                               Add2  Q106234628
# 3                                               Sptb  Q106234628
# 4                      mitfa, dct, tyrp1b, and pmela  Q106248504
# ..                                               ...         ...
# 143  Lrmp, Avil, Trpm5, Dclk1, Gng13, L1cam and Sox9   Q59066334
# 144                                              NaN   Q59770869
# 145                             Slc34a1+ and Atp11a+   Q59770869
# 146                               Atp11a+ and Rnf24+   Q59770869
# 147                                            Daam2   Q59770869
#
#                                              stated as
# 0    "The neuronal glycine transporter, GlyT2, is a...
# 1    "it is likely that combining select markers, i...
# 2    "it is likely that combining select markers, i...
# 3    "it is likely that combining select markers, i...
# 4    "melanophores were detected in Cluster eight b...
# ..                                                 ...
# 143  "the mTEC IV population does not express any c...
# 144  " S1/S2 cells (Slc5a12+, Gatm+, Alpl+, and Slc...
# 145           "S3 type 1 cells (Slc34a1+ and Atp11a+)"
# 146            "S3 type 2 cells (Atp11a+ and Rnf 24+)"
# 147  "New marker gene s were identified, such as Da...
#
# [148 rows x 4 columns]

# %%
def split_markers(marker_string):
    
    marker_string = marker_string.replace("+", " ")
    marker_string = marker_string.replace("(", " ")
    marker_string = marker_string.replace(")", " ")
    
    sep_markers = marker_string.split(",")
    
    return(sep_markers)

# %%
split_markers("GlyT2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6f54cd72e894> in <module>
# ----> 1 split_markers("GlyT2")
#
# <ipython-input-6-ff590b4b59b9> in split_markers(marker_string)
#       5     marker_string = marker_string.replace(")", " ")
#       6
# ----> 7     sep_markers = markers_string.split(",")
#       8
#       9     return(sep_markers)
#
# NameError: name 'markers_string' is not defined

# %%
with open("celltypes_dict.pickle", "rb") as handle:
    subclass_dict = pickle.load(handle)

pwd = getpass.getpass()
login_instance = wdi_login.WDLogin(user="TiagoLubiana", pwd=pwd)

try:
    for index, row in cell_markers.iterrows():
        
        marker_labels = row["marker"]

        data_for_item = []
        stated_in_full_reference = wdi_core.WDItemID(
            value=row["stated in"], prop_nr="P248", is_reference=True
        )
        references = [[stated_in_full_reference]]

        label = row["label"]
        print(f"Running code for {label} ")

        if "human" in label
            ## Look for human gene ID           


        elif "mouse" in label:
            ## Look for mouse gene ID  
            

        elif "zebrafish" in label:
            ## Look for zebrafish gene id
        else:
            description = "cell type"
